# %% [markdown]
# <h2>Evaluación Diagnostica Git/Gitflow IIC2154</h2>
# <p>Alejandro Rico Rozo - Sección 4</p>

# %%
from functions import (
    most_retweeted,
    most_active_users,
    most_active_days,
    most_frecuent_hashtags
)

# %%
from process_file import users, tweets

users = users()
tweets = tweets()

# %%
users.head(3)
# Out:
#           username        displayname               userId  \
# 0   ShashiRajbhar6     Shashi Rajbhar  1015969769760096256
# 1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 3    SukhdevSingh_      Sukhdev Singh  1308356658582618112
#
#                                          description  \
# 0  Satya presan 🤔ho Sakta but prajit💪 nhi\njhuth ...
# 1        ਜਿਓਣਾ ਕੀ ਸਰੀਰਾਂ ਦਾ ਜੇਕਰ ਹੋਣ ਜ਼ਮੀਰਾਂ ਮਰੀਆਂ 🌼
# 3  Just a part of my society . Social and Politic...
#
#                                       rawDescription descriptionUrls  \
# 0  Satya presan 🤔ho Sakta but prajit💪 nhi\njhuth ...              []
# 1        ਜਿਓਣਾ ਕੀ ਸਰੀਰਾਂ ਦਾ ਜੇਕਰ ਹੋਣ ਜ਼ਮੀਰਾਂ ਮਰੀਆਂ 🌼              []
# 3  Just a part of my society . Social and Politic...              []
#
#    verified                    created  followersCount  friendsCount  ...  \
# 0     False  2018-07-08T14:44:03+00:00            1788          1576  ...
# 1     False  2020-11-29T06:40:06+00:00              51            68  ...
# ...

# %%
tweets.head(3)
# Out:
#                                             tweetUrl  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
#
#                                      renderedContent              tweetId  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
#
#                                                 user outlinks tcooutlinks  \
# ...

# %%
top_10_tweets = most_retweeted(tweets)
top_10_tweets
# Out:
#                                              content  retweetCount
# 6  Lets not forget that our Farmers are STILL out...             2
# 3  #StopHateAgainstFarmers support #FarmersProtes...             1
# 0                       Support 👇\n\n#FarmersProtest             0
# 1  Supporting farmers means supporting our countr...             0
# 2  Support farmers if you are related to food #St...             0
# 4  You hate farmers I hate you, \nif you love the...             0
# 5  They can't be farmers. Looks like Gundas are h...             0
# 7  @Troll48611422 @Doabapunjab1 @Terminator00096 ...             0
# 8  Neutrality helps the oppressor, never the vict...             0
# 9  Why You Should Visit the F.A.R.M.E.R. at Tikri...             0

# %%
top_10_users = most_active_users(tweets, users)
top_10_users
# Out:
#           username        displayname               userId
# 0   ShashiRajbhar6     Shashi Rajbhar  1015969769760096256
# 1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1332937272581263362
# 3    SukhdevSingh_      Sukhdev Singh  1308356658582618112
# 4  Davidmu66668113     tera jija 🤨🚩🇺🇸  1357311756532649985
# 5   Abhimanyu_1987     Abhimanyu 🌏 🇮🇳           2918610912
# 6   singhwhotweets      Japneet Singh  1237420463581728768
# 7    J_cheeselover        jerry(ਜੈਰੀ)  1361422240223350784
# 8  DigitalKisanBot        Kisan Bot🚜🌾  1309302936317636608
# 9    rajriarhughes    Raj Riar Hughes   858383035137273856

# %%
top_10_days = most_active_days(tweets)
top_10_days
# Out:
# 2021-03-30    10
# Name: date_day, dtype: int64

# %%
top_10_hashtags = most_frecuent_hashtags(tweets)
top_10_hashtags
# Out:
# {'FarmersProtest': 10, 'StopHateAgainstFarmers': 6}
